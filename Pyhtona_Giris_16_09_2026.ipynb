# %%
ad="afra"
soyad="özcan"
sayı=5
print(f"{ad} {soyad} python öğreniyorum.")
print(sayı)
print("sayı yazdırdık")
# Out:
# afra özcan python öğreniyorum.
# 5
# sayı yazdırdık

# %%
print(ad.lower()) #kücük harflere çevirir hepsini
"""
afra özcan
kahramanmaraş

"""
# Out:
# afra
# '\nafra özcan\nkahramanmaraş\n\n'

# %%
sehir="kahramanmaraş"
print(sehir)
puan=50
print(puan)
puan=75
print(puan)
# Out:
# kahramanmaraş
# 50
# 75

# %%
sayı1=5
osayı=8.75
dogru_mu=True
meslek="öğrenci"
print(type(sayı1))
print(type(osayı))
print(type(dogru_mu))
print(type(meslek))
print(type(10))
print(type("10"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
a=15
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(17%5)
print(2**8)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 2
# 256

# %%
ad=input("isminizi giriniz:")
print(f"merhaba {ad}!")
yas=input("yaşınızı giriniz:")
yas=int(yas)
print(f"10 yıl sonraki yaşınız {yas+10}")
# Out:
# isminizi giriniz:fatma
# merhaba fatma!
# yaşınızı giriniz:40
# 10 yıl sonraki yaşınız 50

# %%
a = 8
b = 12
print( a > b)
print(a<b)
print(a==b)
sayı=input("bir sayı giriniz:")
sayı=int(sayı)
print(sayı==100)
# Out:
# False
# True
# False
# bir sayı giriniz:100
# True

# %%
yas = 22
ogrenci_mi = False
print(yas and ogrenci_mi)
print(yas or ogrenci_mi)
print(not yas)
print(not ogrenci_mi)
print(yas>18 and ogrenci_mi)
# Out:
# False
# 22
# False
# True
# False

# %%
sayı=input("sayı giriniz:")
sayı=int(sayı)
if sayı>0 :
  print("sayı pozitiftir")
if sayı<0:
  print("sayı negatiftir")
# Out:
# sayı giriniz:5
# sayı pozitiftir

# %%
notu=input("notunuzu giriniz:")
notu=int(notu)
if notu>=50:
  print("geçtiniz")
else:
  print("kaldınız")
# Out:
# notunuzu giriniz:49
# kaldınız

# %%
ad="Afra"
soyad="Özcan"
print(f"{ad} {soyad}")
print(len(ad))
print(ad.lower())
print(soyad.upper())
# Out:
# Afra Özcan
# 4
# afra
# ÖZCAN

# %%
sayı1=input("bir sayı giriniz:")
sayı2=input("bir sayı giriniz:")
sayı1=int(sayı1)
sayı2=int(sayı2)
print(sayı1*sayı2)
sayı3=input("bir sayı giriniz:")
sayı3=int(sayı3)
print(sayı3**2)
# Out:
# bir sayı giriniz:6
# bir sayı giriniz:45
# 270
# bir sayı giriniz:6
# 36
